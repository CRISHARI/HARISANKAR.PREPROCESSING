# %% [markdown]
# ##Assignment on preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Load the dataset into python environment

# %%
data=pd.read_csv('titanic_dataset.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 2. Make ‘PassengerId’ as the index column

# %%
data = data.set_index (['PassengerId'])
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ##3.Basic details of the data set

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.shape
# Out:
# (891, 11)

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ##4.Fill all missing values

# %%
data['Age']=data['Age'].fillna(data['Age'].median())

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data['Cabin']=data['Cabin'].ffill().bfill()
data['Embarked']=data['Embarked'].ffill().bfill()

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# ##5.Handle outliers

# %%
num_cols=['Survived','Pclass','SibSp','Age']

# %%
for i in num_cols:
    plt.figure()
    plt.boxplot(data[i])
    plt.title(i)

# %%
Q1=np.percentile(data['SibSp'],25,method='midpoint')
Q2=np.percentile(data['SibSp'],50,method='midpoint')
Q3=np.percentile(data['SibSp'],75,method='midpoint')

# %%
print('Q1 is',Q1)
print('Q2 is',Q2)
print('Q3 is',Q3)
# Out:
# Q1 is 0.0
# Q2 is 0.0
# Q3 is 1.0

# %%
data['SibSp'].median()
# Out:
# 0.0

# %%
IQR=Q3-Q1

# %%
low_lim=Q1-1.5*IQR
up_lim=Q3+1.5*IQR
print('min is',low_lim)
print('max is',up_lim)
# Out:
# min is -1.5
# max is 2.5

# %%
outlier=[]
for x in data['SibSp']:
    if ((x>up_lim) or (x<low_lim)):
     outlier.append(x)

# %%
outlier
# Out:
# [3,
#  4,
#  3,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  3,
#  4,
#  8,
#  4,
#  4,
#  3,
#  8,
#  4,
#  8,
#  3,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  3,
#  5,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  4,
#  8,
#  4,
#  8]

# %%
ind1=data['SibSp']>up_lim
data.loc[ind1].index
# Out:
# Int64Index([  8,  17,  25,  28,  51,  60,  64,  69,  72,  86,  89, 120, 160,
#             165, 172, 177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342,
#             375, 387, 410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788,
#             793, 814, 820, 825, 847, 851, 864],
#            dtype='int64', name='PassengerId')

# %%
ind1=data['SibSp']<low_lim
data.loc[ind1].index
# Out:
# Int64Index([], dtype='int64', name='PassengerId')

# %%
data.drop([  8,  17,  25,  28,  51,  60,  64,  69,  72,  86,  89, 120, 160,
            165, 172, 177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342,
            375, 387, 410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788,
            793, 814, 820, 825, 847, 851, 864],inplace=True)
data.head(25)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 26                  1       3
# 27                  0       3
# 29                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# ...

# %%
for i in num_cols:
    plt.figure()
    plt.boxplot(data[i])
    plt.title(i)

# %%
Q1=np.percentile(data['Age'],25,method='midpoint')
Q2=np.percentile(data['Age'],50,method='midpoint')
Q3=np.percentile(data['Age'],75,method='midpoint')

# %%
print('Q1 is',Q1)
print('Q2 is',Q2)
print('Q3 is',Q3)
# Out:
# Q1 is 23.0
# Q2 is 28.0
# Q3 is 36.0

# %%
data['Age'].median()
# Out:
# 28.0

# %%
IQR=Q3-Q1

# %%
low_lim=Q1-1.5*IQR
up_lim=Q3+1.5*IQR
print('min is',low_lim)
print('max is',up_lim)
# Out:
# min is 3.5
# max is 55.5

# %%
outlier=[]
for x in data['Age']:
    if ((x>up_lim) or (x<low_lim)):
     outlier.append(x)

# %%
outlier
# Out:
# [58.0,
#  66.0,
#  3.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  3.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  3.0,
#  60.0,
#  1.0,
#  3.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind1=data['Age']>up_lim
data.loc[ind1].index
# Out:
# Int64Index([ 12,  34,  55,  95,  97, 117, 171, 175, 196, 233, 253, 269, 276,
#             281, 327, 367, 439, 457, 468, 484, 488, 494, 546, 556, 571, 588,
#             626, 627, 631, 648, 660, 673, 685, 695, 746, 773, 830, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
ind1=data['Age']<low_lim
data.loc[ind1].index
# Out:
# Int64Index([ 44,  79, 173, 184, 194, 206, 298, 306, 341, 349, 382, 408, 470,
#             480, 531, 645, 756, 789, 804, 828, 832],
#            dtype='int64', name='PassengerId')

# %%
data.drop([12,34,55,95,97,117,171,175,196,233,253,269,276,
            281, 327, 367, 439, 457, 468, 484, 488, 494, 546, 556, 571, 588,
            626, 627, 631, 648, 660, 673, 685, 695, 746, 773, 830, 852, 880],inplace=True)
data.head(20)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# ...

# %%
data.drop([44,  79, 173, 184, 194, 206, 298, 306, 341, 349, 382, 408, 470,
            480, 531, 645, 756, 789, 804, 828, 832],inplace=True)
data.head(50)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 26                  1       3
# 27                  0       3
# 29                  1       3
# 30                  0       3
# 31                  0       1
# 32                  1       1
# 33                  1       3
# 35                  0       1
# ...

# %%
for i in num_cols:
    plt.figure()
    plt.boxplot(data[i])
    plt.title(i)

# %% [markdown]
# ##6.MinMax

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
data['Embarked']=le.fit_transform(data['Embarked'])
data['Embarked'].unique()
# Out:
# array([2, 0, 1])

# %%
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Sex']=le.fit_transform(data['Sex'])
data['Sex'].unique()
# Out:
# array([1, 0])

# %%
data['Ticket'].unique()
data['Ticket']=le.fit_transform(data['Ticket'])
data['Ticket'].unique()
# Out:
# array([494, 564, 634,  42, 446, 255,  73, 321, 116, 582, 506, 310, 390,
#        137, 135, 279, 167, 123, 136, 258,  37, 306, 162, 263, 339, 566,
#        554, 268, 568,  38, 185, 485, 280, 169, 478,  45, 368, 262, 583,
#        436,  64, 173, 354, 493, 555, 221,  81, 524, 198, 530, 180,  28,
#        432, 569, 172, 522, 589, 250, 526, 587, 187,  68, 324, 332, 447,
#        408, 282, 289, 260,  23, 602, 641, 617, 276, 277, 318, 643, 519,
#        449, 578, 102, 134, 361, 338, 394, 476, 227, 331, 275, 234, 365,
#        443,   2, 176, 254, 463, 159, 631, 553, 511, 201, 437, 512, 179,
#        295, 357, 605, 508,  96, 521, 595,  47, 475, 560, 186, 309, 633,
#        414, 103, 527, 382,  98, 131, 588,  32, 487, 509, 541, 563, 395,
#        619, 238, 444, 528, 300, 245, 400,  26, 314, 544, 624, 389, 561,
#        153, 542, 594, 251,  30, 434,   9, 411, 363, 107, 209, 383, 571,
#        428, 466, 435, 144, 284, 224, 160, 501, 229, 199, 421,  15, 607,
# ...

# %%
data['Name'].unique()
data['Name']=le.fit_transform(data['Name'])
data['Name'].unique()
# Out:
# array([ 89, 165, 312, 240,  15, 499, 462, 369, 520, 641, 643,  20, 738,
#        318, 762, 737, 459, 241,  62, 470, 673,  31, 213, 544, 713, 727,
#        682, 257, 482, 330, 452, 113, 735, 529,   7, 726, 401, 186, 618,
#        423, 543, 640,  29, 534, 293, 219, 768, 628, 535, 749, 662, 343,
#        296, 689, 505, 536, 161, 396, 354, 334, 140,  69, 491, 684, 508,
#        197, 740, 651, 466, 120, 344, 228, 672, 128, 138,  23, 129, 183,
#        654, 269, 193, 379, 586, 588, 753, 363, 273, 488, 638, 504, 603,
#        497, 597, 776,  50, 374,  33, 575, 725,  53, 321, 496, 519, 745,
#        752, 528, 472, 447, 583, 207, 199, 144, 616, 747, 678, 608, 526,
#        239, 557, 250,  80, 537, 280,  96,  24, 527,  21, 227, 522, 101,
#         51, 573, 479, 783, 551, 761, 255, 159, 674, 162, 744,  64, 108,
#        260, 136, 668,  52, 436, 665, 399, 346, 281, 424, 580, 397, 621,
#        540, 619,  82, 723, 594, 115,  18,  93, 480, 550, 445, 775, 732,
# ...

# %%
data=pd.get_dummies(data)

# %%
data
# Out:
#              Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  \
# PassengerId
# 1                   0       3    89    1  22.0      1      0     494   7.2500
# 2                   1       1   165    0  38.0      1      0     564  71.2833
# 3                   1       3   312    0  26.0      0      0     634   7.9250
# 4                   1       1   240    0  35.0      1      0      42  53.1000
# 5                   0       3    15    1  35.0      0      0     446   8.0500
# ...               ...     ...   ...  ...   ...    ...    ...     ...      ...
# 887                 0       2   493    1  27.0      0      0      87  13.0000
# 888                 1       1   265    0  19.0      0      0      12  30.0000
# 889                 0       3   370    0  28.0      1      2     640  23.4500
# 890                 1       1    63    1  26.0      0      0       6  30.0000
# 891                 0       3   194    1  32.0      0      0     440   7.7500
#
# ...

# %%
minmax = preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
x=minmax.fit_transform(data[['Survived']])

# %%
x=pd.DataFrame(x)

# %%
x.describe()
# Out:
#                 0
# count  785.000000
# mean     0.387261
# std      0.487435
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000
